# %% [markdown]
# <a href="https://colab.research.google.com/github/UW-geophysics-edu/ess-412-512-intro2seismology/blob/main/Global_Phases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Global Phases
#
# This notebook will explore gobal propagation of rays as predicted from 1D Earth models and observed in data.
#
# By Marine Denolle (mdenolle@uw.edu) with help of Obspy tutorials and AI
#
# ## Ray Tracing
#
# Playbook to solve for ray geometry in 2D vertically varying structure and 3D global Earth. We will use the TauP in Obspy, a python project.
#
#
#
# https://docs.obspy.org/packages/obspy.taup.html

# %%
## Install dependencies (for Google Colab)
# !pip install obspy
# Out:
# Requirement already satisfied: obspy in /usr/local/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/site-packages (from obspy) (1.26.4)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.11/site-packages (from obspy) (1.15.3)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/site-packages (from obspy) (3.9.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/site-packages (from obspy) (6.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from obspy) (80.9.0)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.11/site-packages (from obspy) (1.4.54)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/site-packages (from obspy) (5.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from obspy) (2.31.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/site-packages (from sqlalchemy<2->obspy) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (23.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->obspy) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->obspy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->obspy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->obspy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->obspy) (2023.7.22)

# %%
## Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import obspy

# %%
from obspy.taup import TauPyModel
model = TauPyModel(model="iasp91")
arrivals = model.get_travel_times(source_depth_in_km=55,
                                  distance_in_degree=67)
print(arrivals)
# Out:
# 28 arrivals
# 	P phase arrival at 647.041 seconds
# 	pP phase arrival at 662.233 seconds
# 	sP phase arrival at 668.704 seconds
# 	PcP phase arrival at 674.865 seconds
# 	PP phase arrival at 794.992 seconds
# 	PKiKP phase arrival at 1034.098 seconds
# 	pPKiKP phase arrival at 1050.528 seconds
# 	sPKiKP phase arrival at 1056.721 seconds
# 	S phase arrival at 1176.948 seconds
# 	pS phase arrival at 1195.508 seconds
# 	SP phase arrival at 1196.830 seconds
# 	sS phase arrival at 1203.129 seconds
# 	PS phase arrival at 1205.421 seconds
# 	SKS phase arrival at 1239.090 seconds
# 	SKKS phase arrival at 1239.109 seconds
# 	ScS phase arrival at 1239.512 seconds
# 	SKiKP phase arrival at 1242.388 seconds
# 	pSKS phase arrival at 1260.314 seconds
# 	sSKS phase arrival at 1266.921 seconds
# 	SS phase arrival at 1437.427 seconds
# 	PKIKKIKP phase arrival at 1855.271 seconds
# 	SKIKKIKP phase arrival at 2063.564 seconds
# 	PKIKKIKS phase arrival at 2069.756 seconds
# 	SKIKKIKS phase arrival at 2277.857 seconds
# 	PKIKPPKIKP phase arrival at 2353.934 seconds
# 	PKPPKP phase arrival at 2356.426 seconds
# 	PKPPKP phase arrival at 2358.899 seconds
# 	SKIKSSKIKS phase arrival at 3208.155 seconds

# %%
arrivals = model.get_travel_times(source_depth_in_km=100,
                                  distance_in_degree=45,
                                  phase_list=["P", "PSPSPS"])
print(arrivals)
# Out:
# 3 arrivals
# 	P phase arrival at 485.210 seconds
# 	PSPSPS phase arrival at 4983.041 seconds
# 	PSPSPS phase arrival at 5799.249 seconds

# %%
arrivals = model.get_ray_paths(500, 130)
arrivals = model.get_pierce_points(500, 130)

# %%
arrivals = model.get_ray_paths(
    source_depth_in_km=500, distance_in_degree=130, phase_list=["ttbasic"])
ax = arrivals.plot_rays()

# %%
arrivals = model.get_ray_paths(source_depth_in_km=500,
                               distance_in_degree=130,
                               phase_list=["Pdiff", "Sdiff",
                                           "pPdiff", "sSdiff"])

# %%
from obspy.taup import plot_travel_times
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9, 9))
ax = plot_travel_times(source_depth=10, phase_list=["P", "S", "PP"],
                       ax=ax, fig=fig)

# %% [markdown]
# ## Student exercise
#
# Download data from a large earthquakes.
#
# You can find earthquakes on the USGS website: https://www.usgs.gov/programs/earthquake-hazards
#
# Pick a large earthquakes, get his date. Another way to collect earthquake information data is by querying an obspy earthquake catalog

# %%
from obspy.clients.fdsn import Client
client = Client("IRIS")

eq = client.get_events(starttime=obspy.UTCDateTime("2023-01-01T00:00:00"),
                       endtime=obspy.UTCDateTime("2025-01-01T00:00:00"),
                       minmagnitude=7.5)

print(eq)
# find the largest magnitude
mags = [e.magnitudes[0].mag for e in eq]
idx = np.argmax(mags)
eqmax = eq[idx]
starttime = obspy.UTCDateTime(eqmax.origins[0].time)  # Earthquake origin time
endtime = starttime + 3*3600  # End time (3 hour after origin)
# Out:
# 7 Event(s) in Catalog:
# 2024-01-01T07:10:09.474000Z | +37.489, +137.264 | 7.5  mww
# 2023-12-02T14:37:05.568000Z |  +8.487, +126.351 | 7.6  mww
# 2023-05-19T02:57:05.349000Z | -23.190, +170.734 | 7.7  mww
# 2023-05-10T16:02:00.334000Z | -15.628, -174.493 | 7.6  mww
# 2023-02-06T10:24:49.258000Z | +38.023,  +37.203 | 7.5  mww
# 2023-02-06T01:17:34.362000Z | +37.225,  +37.021 | 7.8  mww
# 2023-01-09T17:47:35.057000Z |  -7.064, +130.004 | 7.6  mww

# %% [markdown]
# ### get station information

# %%
inv = client.get_stations(network="II",station="*",channel="BHZ", starttime=starttime, endtime=endtime)
print(inv)
# Out:
# Inventory created at 2026-01-30T19:24:13.797500Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2023-02-...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			II
# 		Stations (44):
# 			II.AAK (Ala Archa, Kyrgyzstan)
# 			II.ABPO (Ambohimpanompo, Madagascar)
# 			II.ALE (Alert, NU, Canada)
# 			II.ARTI (Arti, Russia)
# 			II.ASCN (Butt Crater, Ascension Island)
# 			II.BFO (Black Forest Observatory, Schiltach, Germany)
# 			II.BORG (Borgarfjordur, Asbjarnarstadir, Iceland)
# 			II.BORK (Burabay, Kazakhstan)
# 			II.CMLA (Cha de Macela, Sao Miguel Island, Azores)
# 			II.COCO (West Island, Cocos (Keeling) Islands)
# 			II.DGAR (Diego Garcia, Chagos Islands, Indian Ocean)
# 			II.EFI (Mount Kent, East Falkland Island)
# 			II.ERM (Erimo, Hokkaido Island, Japan)
# 			II.ESK (Eskdalemuir, Scotland, UK)
# 			II.FFC (Flin Flon, Canada)
# 			II.HOPE (Hope Point, South Georgia Island)
# 			II.IBFO (Black Forest Observatory, Schiltach, Germany)
# 			II.JTS (Las Juntas de Abangares, Costa Rica)
# 			II.KAPI (Kappang, Sulawesi, Indonesia)
# 			II.KDAK (Kodiak Island, Alaska, USA)
# 			II.KIV (Kislovodsk, Russia)
# 			II.KURK (Kurchatov, Kazakhstan)
# 			II.KWJN (Gagan, Kwajalein Atoll, Marshall Islands)
# 			II.LVZ (Lovozero, Russia)
# 			II.MBAR (Mbarara, Uganda)
# 			II.MSEY (Mahe, Seychelles)
# 			II.MSVF (Monasavu, Fiji)
# 			II.NIL (Nilore, Pakistan)
# 			II.NNA (Nana, Peru)
# 			II.OBN (Obninsk, Russia)
# 			II.PALK (Pallekele, Sri Lanka)
# 			II.PFO (Pinon Flat, California, USA)
# 			II.RAYN (Ar Rayn, Saudi Arabia)
# 			II.RPN (Rapanui, Easter Island, Chile)
# 			II.SACV (Santiago Island, Cape Verde)
# 			II.SHEL (Horse Pasture, St. Helena Island)
# 			II.SIMI (Simiganj, Tajikistan)
# 			II.SUR (Sutherland, South Africa)
# 			II.TAU (Hobart, Tasmania, Australia)
# 			II.TLY (Talaya, Russia)
# 			II.UOSS (Univ. of Sharjah, Sharjah, United Arab Emirates)
# 			II.WRAB (Tennant Creek, NT, Australia)
# 			II.XBFO (Black Forest Observatory, Schiltach, Germany)
# 			II.XPFO (Pinon Flat, California, USA)
# 		Channels (0):

# %% [markdown]
# ### download waveform data
#
# Using Obspy, download the BHZ channel of the network of stations and append the data into a single array of traces.

# %%
st=[]#obspy.Trace()
for sta in inv[0]:
  print(sta.code)
  try:
    st.append(client.get_waveforms("II", sta.code, "*", "BHZ", starttime, endtime,attach_response=True))  # Get BHZ component data
  except:
    print(f"Could not get data for station {sta.code}")
# Out:
# AAK
# ABPO
# ALE
# ARTI
# ASCN
# BFO
# BORG
# BORK
# CMLA
# COCO
# DGAR
# EFI
# ERM
# ESK
# FFC
# HOPE
# IBFO
# Could not get data for station IBFO
# JTS
# KAPI
# KDAK
# KIV
# KURK
# KWJN
# LVZ
# MBAR
# MSEY
# MSVF
# NIL
# NNA
# OBN
# PALK
# PFO
# RAYN
# RPN
# SACV
# SHEL
# SIMI
# SUR
# TAU
# TLY
# UOSS
# WRAB
# XBFO
# XPFO

# %% [markdown]
# ## calculate angular distance

# %%
from obspy.geodetics import gps2dist_azimuth,locations2degrees


event_latitude = eqmax.origins[0].latitude  # Get event latitude from the first trace
event_longitude = eqmax.origins[0].longitude  # Get event longitude

distances = []
ang_distances = []
for tr in st:
    for network in inv:
        if network.code == tr[0].stats.network:
            for station in network:
                if station.code == tr[0].stats.station:
                  station_latitude = station.latitude
                  station_longitude = station.longitude
    dist, az, baz = gps2dist_azimuth(event_latitude, event_longitude, station_latitude, station_longitude)
    ang = locations2degrees(event_latitude, event_longitude, station_latitude, station_longitude)
    # also get the angular distance

    ang_distances.append(ang)
    distances.append(dist / 1000)  # Convert distance to kilometers
    print(f"Distance between event and station {station.code}: {dist / 1000} km and angular distances: {ang} deg")
# Out:
# Distance between event and station XPFO: 3231.755455843185 km and angular distances: 28.995337138157435 deg
# Distance between event and station XPFO: 6316.710885215381 km and angular distances: 57.06044724142486 deg
# Distance between event and station XPFO: 6056.31786679225 km and angular distances: 54.347935845740516 deg
# Distance between event and station XPFO: 2659.1055542793442 km and angular distances: 23.893344732026343 deg
# Distance between event and station XPFO: 7315.082495540931 km and angular distances: 65.87458261925384 deg
# Distance between event and station XPFO: 2630.448723535671 km and angular distances: 23.612236964830434 deg
# Distance between event and station XPFO: 4846.483993460469 km and angular distances: 43.49822141040581 deg
# Distance between event and station XPFO: 3110.856404112362 km and angular distances: 27.92861418106029 deg
# Distance between event and station XPFO: 5422.055188062806 km and angular distances: 48.647041967881144 deg
# Distance between event and station XPFO: 8298.148035014887 km and angular distances: 74.71602327678761 deg
# Distance between event and station XPFO: 6164.859819771165 km and angular distances: 55.57406347650008 deg
# Distance between event and station XPFO: 13462.719243509893 km and angular distances: 121.2215736277711 deg
# Distance between event and station XPFO: 8480.672923281718 km and angular distances: 76.08469794365386 deg
# Distance between event and station XPFO: 3620.3956889713522 km and angular distances: 32.49871776651847 deg
# Distance between event and station XPFO: 9092.18297679109 km and angular distances: 81.55681153107942 deg
# Distance between event and station XPFO: 12325.187930434266 km and angular distances: 111.0519592535867 deg
# Distance between event and station XPFO: 12008.655435362678 km and angular distances: 107.86585595174384 deg
# Distance between event and station XPFO: 9705.615790532991 km and angular distances: 87.27783383934398 deg
# Distance between event and station XPFO: 9437.192267769386 km and angular distances: 84.64977475247528 deg
# Distance between event and station XPFO: 887.4903242011982 km and angular distances: 7.983105395532806 deg
# Distance between event and station XPFO: 3599.2282383181273 km and angular distances: 32.300193304133565 deg
# Distance between event and station XPFO: 12733.867445022928 km and angular distances: 114.38658400369908 deg
# Distance between event and station XPFO: 3416.2180093920038 km and angular distances: 30.701559012563013 deg
# Distance between event and station XPFO: 4237.8404800253775 km and angular distances: 38.27154931480509 deg
# Distance between event and station XPFO: 5018.202600673051 km and angular distances: 45.291723994226174 deg
# Distance between event and station XPFO: 15652.371814556427 km and angular distances: 140.71567575630118 deg
# Distance between event and station XPFO: 3294.935061265626 km and angular distances: 29.567530491848746 deg
# Distance between event and station XPFO: 12919.452122098088 km and angular distances: 116.15194020694227 deg
# Distance between event and station XPFO: 1988.793228230105 km and angular distances: 17.892160590748407 deg
# Distance between event and station XPFO: 5515.642954326009 km and angular distances: 49.62386750092375 deg
# Distance between event and station XPFO: 11696.525392164736 km and angular distances: 104.9796097958243 deg
# Distance between event and station XPFO: 1722.105457183742 km and angular distances: 15.51677338536891 deg
# Distance between event and station XPFO: 16680.781068136785 km and angular distances: 149.9738602917388 deg
# Distance between event and station XPFO: 6428.309311829711 km and angular distances: 57.75457445783515 deg
# Distance between event and station XPFO: 7397.841269931404 km and angular distances: 66.69063919853902 deg
# Distance between event and station XPFO: 2802.0064515972354 km and angular distances: 25.13933332091933 deg
# Distance between event and station XPFO: 7887.533366896576 km and angular distances: 71.23045376991777 deg
# Distance between event and station XPFO: 14212.021699437779 km and angular distances: 127.89432089006463 deg
# Distance between event and station XPFO: 5338.383007739361 km and angular distances: 47.892723977434464 deg
# Distance between event and station XPFO: 2273.5245808506374 km and angular distances: 20.4412929815461 deg
# Distance between event and station XPFO: 11957.793174753951 km and angular distances: 107.56980725188674 deg
# Distance between event and station XPFO: 2630.448723535671 km and angular distances: 23.612236964830434 deg
# Distance between event and station XPFO: 11696.562909102979 km and angular distances: 104.97994701317728 deg

# %% [markdown]
# ## calculate travel times

# %%
model = TauPyModel(model="iasp91")
travel_times = []
for dist in ang_distances:
  arrivals = model.get_travel_times(source_depth_in_km=eqmax.origins[0].depth/1000, distance_in_degree=dist, phase_list=["P"])
  print(arrivals)
  if len(arrivals):
    travel_times.append(arrivals[0].time)
  else:
    travel_times.append(np.nan)
# Out:
# 1 arrivals
# 	P phase arrival at 359.838 seconds
# 1 arrivals
# 	P phase arrival at 586.150 seconds
# 1 arrivals
# 	P phase arrival at 566.658 seconds
# 3 arrivals
# 	P phase arrival at 313.811 seconds
# 	P phase arrival at 314.279 seconds
# 	P phase arrival at 315.792 seconds
# 1 arrivals
# 	P phase arrival at 645.802 seconds
# 3 arrivals
# 	P phase arrival at 311.240 seconds
# 	P phase arrival at 311.339 seconds
# 	P phase arrival at 313.064 seconds
# 1 arrivals
# 	P phase arrival at 483.370 seconds
# 3 arrivals
# 	P phase arrival at 350.335 seconds
# 	P phase arrival at 355.139 seconds
# 	P phase arrival at 355.140 seconds
# 1 arrivals
# 	P phase arrival at 523.950 seconds
# 1 arrivals
# 	P phase arrival at 699.955 seconds
# 1 arrivals
# 	P phase arrival at 575.535 seconds
# 0 arrivals
#
# 1 arrivals
# 	P phase arrival at 707.822 seconds
# 1 arrivals
# 	P phase arrival at 390.720 seconds
# 1 arrivals
# 	P phase arrival at 737.871 seconds
# 0 arrivals
#
# 0 arrivals
#
# 1 arrivals
# 	P phase arrival at 766.809 seconds
# 1 arrivals
# 	P phase arrival at 753.837 seconds
# 3 arrivals
# 	P phase arrival at 116.038 seconds
# 	P phase arrival at 138.395 seconds
# 	P phase arrival at 138.395 seconds
# 1 arrivals
# 	P phase arrival at 388.983 seconds
# 0 arrivals
#
# 1 arrivals
# 	P phase arrival at 374.932 seconds
# 1 arrivals
# 	P phase arrival at 440.292 seconds
# 1 arrivals
# 	P phase arrival at 497.719 seconds
# 0 arrivals
#
# 1 arrivals
# 	P phase arrival at 364.907 seconds
# 0 arrivals
#
# 7 arrivals
# 	P phase arrival at 248.924 seconds
# 	P phase arrival at 249.550 seconds
# 	P phase arrival at 250.409 seconds
# 	P phase arrival at 251.344 seconds
# 	P phase arrival at 251.350 seconds
# 	P phase arrival at 258.568 seconds
# 	P phase arrival at 258.572 seconds
# 1 arrivals
# 	P phase arrival at 531.435 seconds
# 0 arrivals
#
# 5 arrivals
# 	P phase arrival at 218.800 seconds
# 	P phase arrival at 219.055 seconds
# 	P phase arrival at 219.178 seconds
# 	P phase arrival at 223.240 seconds
# 	P phase arrival at 223.382 seconds
# 0 arrivals
#
# 1 arrivals
# 	P phase arrival at 591.052 seconds
# 1 arrivals
# 	P phase arrival at 651.040 seconds
# 3 arrivals
# 	P phase arrival at 325.170 seconds
# 	P phase arrival at 327.169 seconds
# 	P phase arrival at 327.912 seconds
# 1 arrivals
# 	P phase arrival at 679.290 seconds
# 0 arrivals
#
# 1 arrivals
# 	P phase arrival at 518.123 seconds
# 5 arrivals
# 	P phase arrival at 277.475 seconds
# 	P phase arrival at 279.601 seconds
# 	P phase arrival at 279.700 seconds
# 	P phase arrival at 282.100 seconds
# 	P phase arrival at 282.553 seconds
# 0 arrivals
#
# 3 arrivals
# 	P phase arrival at 311.240 seconds
# 	P phase arrival at 311.339 seconds
# 	P phase arrival at 313.064 seconds
# 0 arrivals

# %% [markdown]
# ## Plot vertical seismogram
#
# Make a plot of the vertical seismograms as a function of

# %%
from obspy.signal.trigger import classic_sta_lta
fig, ax = plt.subplots(figsize=(10, 6))


  # STA/LTA parameters
sta_window = 5 # Short-term window in seconds
lta_window = 1000  # Long-term window in seconds

for i, tr in enumerate(st):
  time_shift = 0#travel_times[i]  # Shift the time axis by the travel time
  newtr = tr.copy()[0] # some stations may have several sensors at the same site, just pick the first one.
  # filter and resample data
  newtr.filter("bandpass", freqmin=0.001, freqmax=1)
  newtr.resample(10)
  # normalize data
  newtr.data/=np.max(np.abs(newtr.data))

  # create sta/lta filter
  # newtr.taper(0.05, type='cosine')


  # Convert to sample points
  sta_samples = int(sta_window / newtr.stats.delta)
  lta_samples = int(lta_window / newtr.stats.delta)

  # Compute STA/LTA function
  impulsivity = classic_sta_lta(newtr.data, sta_samples, lta_samples)


  ax.plot(impulsivity+ang_distances[i],newtr.times()/3600, "k")  # Plot the trace with an offset for visualization
  # ax.plot(newtr.data+ang_distances[i],newtr.times()/3600, "k")  # Plot the trace with an offset for visualization

  # plot markers for the predicted arrival times of P waves
  ax.scatter(ang_distances[i], travel_times[i]/3600, marker="x", color="r")

ax.set_xlabel("Angular Distance (°)")
ax.set_ylabel("Time (hour)")
ax.set_title("Vertical Seismograms ")
plt.show()
